# %%
from generate_data import generate_data_onfly, load_data_from_csv

# ds = generate_data_onfly(num_samples=1, graph_size=20)
# Lấy dữ liệu từ dataset
# for depo, graphs, demand in ds.take(1):  # Lấy phần tử đầu tiên
#     print("Depo (tọa độ của depo):")
#     print(depo.numpy())  # In tọa độ của depo

#     print("\nGraphs (tọa độ của các điểm khách hàng):")
#     print(graphs.numpy())  # In tọa độ của các điểm khách hàng

#     print("\nDemand (nhu cầu của các điểm):")
#     print(demand.numpy()) 
#     print("\n\n")

csv_path = r"E:\Innter\R201_50.csv"

# Tải dữ liệu từ CSV
dataset = load_data_from_csv(csv_path, normalize_capacity=100)

# Hiển thị dữ liệu
for depo, graphs, demand in dataset.take(2):
    print("Depo (tọa độ của depo):")
    print(depo.numpy())

    print("\nGraphs (tọa độ của các điểm khách hàng):")
    print(graphs.numpy())  # Chỉ chứa [['XCOORD.', 'YCOORD.']]

    print("\nDemand (nhu cầu của các điểm):")
    print(demand.numpy())
# Out:
# Depo (tọa độ của depo):
# [35. 35.]
#
# Graphs (tọa độ của các điểm khách hàng):
# [[41. 49.]
#  [35. 17.]
#  [55. 45.]
#  [55. 20.]
#  [15. 30.]
#  [25. 30.]
#  [20. 50.]
#  [10. 43.]
#  [55. 60.]
#  [30. 60.]
#  [20. 65.]
#  [50. 35.]
#  [30. 25.]
#  [15. 10.]
#  [30.  5.]
#  [10. 20.]
#  [ 5. 30.]
#  [20. 40.]
#  [15. 60.]
#  [45. 65.]
#  [45. 20.]
#  [45. 10.]
#  [55.  5.]
#  [65. 35.]
#  [65. 20.]
#  [45. 30.]
#  [35. 40.]
#  [41. 37.]
#  [64. 42.]
#  [40. 60.]
#  [31. 52.]
#  [35. 69.]
#  [53. 52.]
#  [65. 55.]
#  [63. 65.]
#  [ 2. 60.]
#  [20. 20.]
#  [ 5.  5.]
#  [60. 12.]
#  [40. 25.]
#  [42.  7.]
#  [24. 12.]
#  [23.  3.]
#  [11. 14.]
#  [ 6. 38.]
#  [ 2. 48.]
#  [ 8. 56.]
#  [13. 52.]
#  [ 6. 68.]
#  [47. 47.]]
#
# Demand (nhu cầu của các điểm):
# [0.1  0.07 0.13 0.19 0.26 0.03 0.05 0.09 0.16 0.16 0.12 0.19 0.23 0.2
#  0.08 0.19 0.02 0.12 0.17 0.09 0.11 0.18 0.29 0.03 0.06 0.17 0.16 0.16
#  0.09 0.21 0.27 0.23 0.11 0.14 0.08 0.05 0.08 0.16 0.31 0.09 0.05 0.05
# ...
